# %%
# pip install tweepy

# %%
import tweepy

# %%
# fill following info
consumer_key = 
consumer_secret = 
access_token = 
access_token_secret = 

screen_name =

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

# public_tweets = api.home_timeline()
# for tweet in public_tweets:
#     print(tweet.text)

# %%
friends = api.get_friends()

# %%
for f in friends:
    print(f)
# Out:
# User(_api=<tweepy.api.API object at 0x10f4a5100>, _json={'id': 761493994714959872, 'id_str': '761493994714959872', 'name': 'Claire🦇🔊', 'screen_name': '0x68Claire', 'location': '', 'description': '🦇🔊', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 66, 'friends_count': 764, 'listed_count': 0, 'created_at': 'Fri Aug 05 09:28:11 +0000 2016', 'favourites_count': 62, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 52, 'lang': None, 'status': {'created_at': 'Thu Nov 11 06:34:50 +0000 2021', 'id': 1458684627061596162, 'id_str': '1458684627061596162', 'text': 'RT @Chris_Defi: 投资的本质，是从价值发现到价格发现的过程：\n1，价值发现的前提是你有非常强的投资框架和逻辑，这对需要对宏观叙事以及天花板的想象力的能力。', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'Chris_Defi', 'name': '匿名博士', 'id': 1268846851253366784, 'id_str': '1268846851253366784', 'indices': [3, 14]}], 'urls': []}, 'source': '<a href="https://mo
# ...

# %%
tweet = "hi {}, check the tweet from python #tweepy".format(screen_name)
status = api.update_status(status=tweet)

# %%
import time

ids = []
for page in tweepy.Cursor(api.get_friend_ids, screen_name="0x68Claire").pages():
    ids.extend(page)
    time.sleep(60)

# screen_names = [user.screen_name for user in api.lookup_users(user_ids=ids)]

# %%
len(ids)
# Out:
# 772

# %%
screen_names = []

remaining = len(ids)%100   
size = len(ids)-remaining

start, end, step = 0, 100, 100

for i in range(int(size/100)):
    print('{} to {}'.format(start, end))
    tmp = ids[start : end]
    screen_names.extend(user.screen_name for user in api.lookup_users(user_ids=tmp))
    start += step
    end += step
# Out:
# Unexpected parameter: user_ids
# 0 to 100
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# <ipython-input-38-0b52fab84ece> in <module>
#       9     print('{} to {}'.format(start, end))
#      10     tmp = ids[start : end]
# ---> 11     screen_names.extend(user.screen_name for user in api.lookup_users(user_ids=tmp))
#      12     start += step
#      13     end += step
#
# ~/Library/Python/3.8/lib/python/site-packages/tweepy/api.py in wrapper(*args, **kwargs)
#      44             kwargs['payload_list'] = payload_list
#      45             kwargs['payload_type'] = payload_type
# ---> 46             return method(*args, **kwargs)
#      47         wrapper.payload_list = payload_list
#      48         wrapper.payload_type = payload_type
#
# ~/Library/Python/3.8/lib/python/site-packages/tweepy/api.py in lookup_users(self, screen_name, user_id, **kwargs)
# ...

# %%
import pandas as pd

def get_friends_df(api, screen_name):

    df = pd.DataFrame()
    friend_name = []
    description = []
    followers_count = []
    url = []
    location = []
    i = 1

    for user in tweepy.Cursor(api.get_friends, screen_name=screen_name).items():

        print('{}: {}'.format(i, user.screen_name))
        friend_name.append(user.screen_name)
        description.append(user.description)
        followers_count.append(user.followers_count)
        url.append(user.url)
        location.append(user.location)
        i += 1
        if i % 50 == 0:
            time.sleep(60)
            print('sleeping...')

    df['friend_name'] = friend_name
    df['description'] = description
    df['followers_count'] = followers_count
    df['url'] = url
    df['location'] = location
    return df

# %%
df = get_friends_df(api)
# Out:
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# <ipython-input-57-fe8b4efaed07> in <module>
# ----> 1 df = get_friends_df(api)
#
# <ipython-input-56-c13f1216c27d> in get_friends_df(api, screen_name)
#       9     i = 1
#      10
# ---> 11     for user in tweepy.Cursor(api.get_friends, screen_name=screen_name).items():
#      12
#      13         print('{}: {}'.format(i, user.screen_name))
#
# ~/Library/Python/3.8/lib/python/site-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# ~/Library/Python/3.8/lib/python/site-packages/tweepy/cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     285             # Reached end of current page, get the next page...
# ...

# %%
df.head()
# Out:
#      friend_name                                        description  \
# 0      yongkunnn  Initiator of @eaguild, a lootverse eastern gui...
# 1      xdaichain  The xDai Chain is a stable payments blockchain...
# 2     BanklessHQ  It’s time to break up with your bank, and join...
# 3  StarkWareLabs                        A @StarkWareLtd experiment.
# 4       MetisDAO  Layer2 Ethereum Rollup. few-sec/cent tx, cheap...
#
#    followers_count                      url   location
# 0             2820                     None      Earth
# 1            47995  https://t.co/JqFw0kASNC
# 2           116264  https://t.co/tA2XKcgNzf   Internet
# 3              607  https://t.co/5IxO68Gjni   on-chain
# 4            63329  https://t.co/jGctGBUuNM  Worldwide

# %%
df.sort_values(by='followers_count', ascending=False, inplace=True)

# %%
df.head(10)
# Out:
#         friend_name                                        description  \
# 233  100trillionUSD  https://t.co/Ry7rqPRR8t\n#bitcoin only - Not f...
# 11        cryptocom  https://t.co/hcDm4vdJaJ - the best place to bu...
# 113          solana  Build Crypto Apps that Scale. ☀️ Solana is a f...
# 72         woonomic  #Bitcoin on-chain analyst: extracting investme...
# 239    AxieInfinity  🏹 Battle 👀  Collect ⟠ Earn // ✨ Economic freed...
# 244  Bybit_Official  💁 Official Support: @BybitHelpdesk | #Bybit’s ...
# 6           sequoia  We help the daring build legendary companies f...
# 90      solanium_io  For the Community, By the Community. \n\nIDO L...
# 247   avalancheavax  Avalanche is the fastest smart contracts platf...
# 273      BoredApeYC  To become a member, buy an ape on OpenSea: htt...
#
#      followers_count                      url              location
# 233          1500782  https://t.co/yz9t8nwhv0  NOT FINANCIAL ADVICE
# 11           1179861  https://t.co/6IAqT3s5BN
# ...

# %%
import datetime

df.to_csv('friend_list_{}_{}.csv'.format(screen_name, datetime.datetime.now().strftime('%Y-%m-%d')), index=False)
